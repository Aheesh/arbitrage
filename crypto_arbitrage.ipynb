# %% [markdown]
# ## Crypto Arbitrage
#
# In this Challenge, you'll take on the role of an analyst at a high-tech investment firm. The vice president (VP) of your department is considering arbitrage opportunities in Bitcoin and other cryptocurrencies. As Bitcoin trades on markets across the globe, can you capitalize on simultaneous price dislocations in those markets by using the powers of Pandas?
#
# For this assignment, you’ll sort through historical trade data for Bitcoin on two exchanges: Bitstamp and Coinbase. Your task is to apply the three phases of financial analysis to determine if any arbitrage opportunities exist for Bitcoin.
#
# This aspect of the Challenge will consist of 3 phases.
#
# 1. Collect the data.
#
# 2. Prepare the data.
#
# 3. Analyze the data.

# %% [markdown]
# ###  Import the required libraries and dependencies.

# %%
import pandas as pd
from pathlib import Path
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Collect the Data
#
# To collect the data that you’ll need, complete the following steps:
#
# Instructions.
#
# 1. Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.
#
# 2. Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.
#
# 3. Repeat Steps 1 and 2 for `coinbase.csv` file.

# %% [markdown]
# ### Step 1: Using the Pandas `read_csv` function and the `Path` module, import the data from `bitstamp.csv` file, and create a DataFrame called `bitstamp`. Set the DatetimeIndex as the Timestamp column, and be sure to parse and format the dates.

# %%
# Read in the CSV file called "bitstamp.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Date"
# Set the parse_dates and infer_datetime_format parameters
bitstamp = pd.read_csv(Path('./Resources/bitstamp.csv'),
                           index_col='Timestamp',
                           infer_datetime_format=True,
                           parse_dates=True)

# %% [markdown]
# ### Step 2: Use the `head` (and/or the `tail`) function to confirm that Pandas properly imported the data.

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
display('----------------------------------------------------------------------------------------------')
display('***************************** FIRST 5 ROWS bitstamp df ****************************')
display('----------------------------------------------------------------------------------------------')
display(bitstamp.head())
display('----------------------------------------------------------------------------------------------')
display('***************************** LAST 5 ROWS bitstamp df ****************************')
display('----------------------------------------------------------------------------------------------')
display(bitstamp.tail())
# Out:
# '----------------------------------------------------------------------------------------------'
# '***************************** FIRST 5 ROWS bitstamp df ****************************'
# '----------------------------------------------------------------------------------------------'
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13681.04  13681.04  13637.93  $13646.48    3.334553
# 2018-01-01 00:01:00  13646.48  13658.75  13610.18  $13658.75    2.663188
# 2018-01-01 00:02:00  13616.93  13616.93  13610.06  $13610.22    0.084653
# 2018-01-01 00:03:00  13610.27  13639.09  13610.27  $13639.09    7.182986
# 2018-01-01 00:04:00  13635.35  13636.35  13620.00   $13620.0    1.069665
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  45482.128785    13639.647479
# 2018-01-01 00:01:00  36361.390888    13653.332816
# 2018-01-01 00:02:00   1152.144036    13610.136247
# ...

# %% [markdown]
# ### Step 3: Repeat Steps 1 and 2 for `coinbase.csv` file.

# %%
# Read in the CSV file called "coinbase.csv" using the Path module. 
# The CSV file is located in the Resources folder.
# Set the index to the column "Timestamp"
# Set the parse_dates and infer_datetime_format parameters
coinbase = pd.read_csv(Path('./Resources/coinbase.csv'),
                           index_col='Timestamp',
                           infer_datetime_format=True,
                           parse_dates=True)

# %%
# Use the head (and/or tail) function to confirm that the data was imported properly.
# Use the head (and/or tail) function to confirm that the data was imported properly.
display('----------------------------------------------------------------------------------------------')
display('***************************** FIRST 5 ROWS coinbase df ****************************')
display('----------------------------------------------------------------------------------------------')
display(coinbase.head())
display('----------------------------------------------------------------------------------------------')
display('***************************** LAST 5 ROWS coinbase df ****************************')
display('----------------------------------------------------------------------------------------------')
display(coinbase.tail())
# Out:
# '----------------------------------------------------------------------------------------------'
# '***************************** FIRST 5 ROWS coinbase df ****************************'
# '----------------------------------------------------------------------------------------------'
#                          Open      High       Low      Close  BTC Volume  \
# Timestamp
# 2018-01-01 00:00:00  13620.00  13620.00  13608.49  $13608.49   20.812754
# 2018-01-01 00:01:00  13607.14  13607.14  13601.66  $13601.66   13.474359
# 2018-01-01 00:02:00  13601.44  13601.44  13580.00   $13580.0   11.536360
# 2018-01-01 00:03:00  13587.31  13587.31  13542.70  $13550.34   16.328039
# 2018-01-01 00:04:00  13550.34  13585.95  13550.34  $13583.44    9.955364
#
#                        USD Volume  Weighted Price
# Timestamp
# 2018-01-01 00:00:00  283451.08537    13619.105106
# 2018-01-01 00:01:00  183283.97801    13602.426919
# 2018-01-01 00:02:00  156789.19686    13590.872506
# ...

# %% [markdown]
# ## Prepare the Data
#
# To prepare and clean your data for analysis, complete the following steps:
#
# 1. For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.
#
# 2. Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.
#
# 3. Convert the data type of the Close column to a `float`.
#
# 4. Review the data for duplicated values, and drop them if necessary.
#
# 5. Repeat Steps 1–4 for the coinbase DataFrame.

# %% [markdown]
# ### Step 1: For the bitstamp DataFrame, replace or drop all `NaN`, or missing, values in the DataFrame.

# %%
# For the bitstamp DataFrame, replace or drop all NaNs or missing values in the DataFrame
# YOUR CODE HERE

display("***************************** Checking for Nulls in DF ****************************")
# check if there are null values in dataframe
display(bitstamp.isna().sum())

# replacing na with mean column value.
bitstamp=bitstamp.fillna(bitstamp.mean())

# check if there are null values in dataframe
display("***************************** Checking for Nulls after replacing null values with mean ****************************")
display(bitstamp.isna().sum())
# Out:
# '***************************** Checking for Nulls in DF ****************************'
# Open              473
# High              473
# Low               473
# Close               0
# BTC Volume        473
# USD Volume        473
# Weighted Price    473
# dtype: int64
# '***************************** Checking for Nulls after replacing null values with mean ****************************'
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64

# %% [markdown]
# ### Step 2: Use the `str.replace` function to remove the dollar signs ($) from the values in the Close column.

# %%
# Use the str.replace function to remove the dollar sign, $
# YOUR CODE HERE

display("***************************** Check for Data types in DF ****************************")

#check the data types for the existing columns in df
display(bitstamp.dtypes)

display("***************************** Checking for $ symbol in Close 'column' rest being float64 columns ****************************")

#close column check for rows with $ symbol
display(bitstamp['Close'].str.contains('$',regex=False))

#close column replace $ symbol
display("***************************** Replacing $ symbol in Close 'column' rest being  float64 ****************************")
bitstamp['Close']=bitstamp['Close'].str.replace('$','',regex=True)
display(bitstamp['Close'].str.contains('$',regex=False))

display(bitstamp.dtypes)
# Out:
# '***************************** Check for Data types in DF ****************************'
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object
# "***************************** Checking for $ symbol in Close 'column' rest being float64 columns ****************************"
# Timestamp
# 2018-01-01 00:00:00    True
# 2018-01-01 00:01:00    True
# 2018-01-01 00:02:00    True
# 2018-01-01 00:03:00    True
# 2018-01-01 00:04:00    True
#                        ...
# 2018-03-31 23:55:00    True
# 2018-03-31 23:56:00    True
# 2018-03-31 23:57:00    True
# 2018-03-31 23:58:00    True
# 2018-03-31 23:59:00    True
# Name: Close, Length: 129540, dtype: bool
# "***************************** Replacing $ symbol in Close 'column' rest being  float64 ****************************"
# Timestamp
# 2018-01-01 00:00:00    False
# ...

# %% [markdown]
# ### Step 3: Convert the data type of the Close column to a `float`.

# %%
# Convert the Close data type to a float
# YOUR CODE HERE
display("***************************** Converting to float and checking DF data type ****************************")

bitstamp['Close']=bitstamp['Close'].astype("float")
display(" bitstamp df ===>",bitstamp.dtypes)
# Out:
# '***************************** Converting to float and checking DF data type ****************************'
# ' bitstamp df ===>'
# Open              float64
# High              float64
# Low               float64
# Close             float64
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object

# %% [markdown]
# ### Step 4: Review the data for duplicated values, and drop them if necessary.

# %%
# Review the data for duplicate values, and drop them if necessary
# YOUR CODE HERE
display("Duplicate rows in bitstamp df : ",bitstamp.duplicated().sum())
bitstamp=bitstamp.drop_duplicates()

display("****************************** Duplicates Dropped from DF*************************")
display("Duplicate rows in bitstamp df : ",bitstamp.duplicated().sum())
# Out:
# 'Duplicate rows in bitstamp df : '
# 472
# '****************************** Duplicates Dropped from DF*************************'
# 'Duplicate rows in bitstamp df : '
# 0

# %% [markdown]
# ### Step 5: Repeat Steps 1–4 for the coinbase DataFrame.

# %%
# Repeat Steps 1–4 for the coinbase DataFrame
# YOUR CODE HERE

display("***************************** Checking for Nulls in DF ****************************")
# check if there are null values in dataframe
display(coinbase.isna().sum())

# replacing na with mean column value.
coinbase=coinbase.fillna(coinbase.mean())

# check if there are null values in dataframe
display("***************************** Checking for Nulls after replacing null values with mean ****************************")
display(coinbase.isna().sum())

display("***************************** Check for Data types in DF ****************************")

#check the data types for the existing columns in df
display(coinbase.dtypes)

display("***************************** Checking for $ symbol in Close 'column' rest being float64 columns ****************************")

#close column check for rows with $ symbol
display(coinbase['Close'].str.contains('$',regex=False))

#close column replace $ symbol
display("***************************** Replacing $ symbol in Close 'column' rest being  float64 ****************************")
coinbase['Close']=coinbase['Close'].str.replace('$','',regex=True)
display(coinbase['Close'].str.contains('$',regex=False))
display(coinbase.dtypes)

display("***************************** Converting to float and checking DF data type ****************************")
coinbase['Close']=coinbase['Close'].astype("float")
display("coinbase df ===>",coinbase.dtypes)

display("Duplicate rows in coinbase df : ",coinbase.duplicated().sum())

coinbase=coinbase.drop_duplicates()

display("****************************** Duplicates Dropped from DF*************************")
display("Duplicate rows in coinbase df : ",coinbase.duplicated().sum())
# Out:
# '***************************** Checking for Nulls in DF ****************************'
# Open              218
# High              218
# Low               218
# Close               0
# BTC Volume        218
# USD Volume        218
# Weighted Price    218
# dtype: int64
# '***************************** Checking for Nulls after replacing null values with mean ****************************'
# Open              0
# High              0
# Low               0
# Close             0
# BTC Volume        0
# USD Volume        0
# Weighted Price    0
# dtype: int64
# '***************************** Check for Data types in DF ****************************'
# Open              float64
# High              float64
# Low               float64
# Close              object
# BTC Volume        float64
# USD Volume        float64
# Weighted Price    float64
# dtype: object
# "***************************** Checking for $ symbol in Close 'column' rest being float64 columns ****************************"
# ...

# %% [markdown]
# ## Analyze the Data
#
# Your analysis consists of the following tasks:
#
# 1. Choose the columns of data on which to focus your analysis.
#
# 2. Get the summary statistics and plot the data.
#
# 3. Focus your analysis on specific dates.
#
# 4. Calculate the arbitrage profits.

# %% [markdown]
# ### Step 1: Choose columns of data on which to focus your analysis.
#
# Select the data you want to analyze. Use `loc` or `iloc` to select the following columns of data for both the bitstamp and coinbase DataFrames:
#
# * Timestamp (index)
#
# * Close

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from bitstamp DataFrame
bitstamp_sliced = bitstamp.loc[:,'Close']

# Review the first five rows of the DataFrame
# YOUR CODE HERE
bitstamp_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13646.48
# 2018-01-01 00:01:00    13658.75
# 2018-01-01 00:02:00    13610.22
# 2018-01-01 00:03:00    13639.09
# 2018-01-01 00:04:00    13620.00
# Name: Close, dtype: float64

# %%
# Use loc or iloc to select `Timestamp (the index)` and `Close` from coinbase DataFrame
coinbase_sliced = coinbase.loc[:,'Close']

# Review the first five rows of the DataFrame
coinbase_sliced.head()
# Out:
# Timestamp
# 2018-01-01 00:00:00    13608.49
# 2018-01-01 00:01:00    13601.66
# 2018-01-01 00:02:00    13580.00
# 2018-01-01 00:03:00    13550.34
# 2018-01-01 00:04:00    13583.44
# Name: Close, dtype: float64

# %% [markdown]
# ### Step 2: Get summary statistics and plot the data.
#
# Sort through the time series data associated with the bitstamp and coinbase DataFrames to identify potential arbitrage opportunities. To do so, complete the following steps:
#
# 1. Generate the summary statistics for each DataFrame by using the `describe` function.
#
# 2. For each DataFrame, create a line plot for the full period of time in the dataset. Be sure to tailor the figure size, title, and color to each visualization.
#
# 3. In one plot, overlay the visualizations that you created in Step 2 for bitstamp and coinbase. Be sure to adjust the legend and title for this new visualization.
#
# 4. Using the `loc` and `plot` functions, plot the price action of the assets on each exchange for different dates and times. Your goal is to evaluate how the spread between the two exchanges changed across the time period that the datasets define. Did the degree of spread change as time progressed?

# %%
# Generate the summary statistics for the bitstamp DataFrame
# YOUR CODE HERE
bitstamp_sliced.describe()
# Out:
# count    129067.000000
# mean      10459.842453
# std        2315.976088
# min        5944.000000
# 25%        8613.370000
# 50%       10145.950000
# 75%       11444.810000
# max       17234.980000
# Name: Close, dtype: float64

# %%
# Generate the summary statistics for the coinbase DataFrame
# YOUR CODE HERE
coinbase_sliced.describe()
# Out:
# count    129322.000000
# mean      10449.140958
# std        2317.197419
# min        5882.310000
# 25%        8609.230000
# 50%       10137.440000
# 75%       11397.237500
# max       17177.990000
# Name: Close, dtype: float64

# %%
# Create a line plot for the bitstamp DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
# bitstamp_sliced.plot(kind='line', legend=True, figsize=(15,10), title='2018 BTC on Bitstamp', color='orange', label='Bitstamp')
bitstamp['Close'].loc[:].plot(kind='line', legend=True, figsize=(15,10), title='2018 BTC Closing price on Bitstamp', color='orange', label='Bitstamp')
# Out:
# <AxesSubplot:title={'center':'2018 BTC Closing price on Bitstamp'}, xlabel='Timestamp'>

# %%
# Create a line plot for the coinbase DataFrame for the full length of time in the dataset 
# Be sure that the figure size, title, and color are tailored to each visualization
# YOUR CODE HERE
coinbase['Close'].loc[:].plot(kind='line', legend=True,title='2018 BTC Closing price on Coinbase', figsize=(15,10),color='blue',label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'2018 BTC Closing price on Coinbase'}, xlabel='Timestamp'>

# %%
# Overlay the visualizations for the bitstamp and coinbase DataFrames in one plot
# The plot should visualize the prices over the full lenth of the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE
bitstamp['Close'].loc[:].plot(kind='line', legend=True, figsize=(15,10),title='2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc[:].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period early in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label
# YOUR CODE HERE
bitstamp['Close'].loc['2018-01-01':'2018-01-31'].plot(kind='line', legend=True, figsize=(15,10),title='January 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-01-01':'2018-01-31'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'January 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Using the loc and plot functions, create an overlay plot that visualizes 
# the price action of both DataFrames for a one month period later in the dataset
# Be sure to include the parameters: legend, figure size, title, and color and label 
# YOUR CODE HERE
bitstamp['Close'].loc['2018-02'].plot(kind='line', legend=True, figsize=(15,10),title='February 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-02'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')

#Jan 28th, Feb 24th, March 31st
# Out:
# <AxesSubplot:title={'center':'February 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %% [markdown]
# **Question** Based on the visualizations of the different time periods, has the degree of spread change as time progressed?
#
# **Answer** Yes, based on the visualization, the spread was wider around 13th Jan 2018 and 29th Jan 2018. In the following month of February 2018, the spread appears to be much tighter.

# %% [markdown]
# ### Step 3: Focus Your Analysis on Specific Dates
#
# Focus your analysis on specific dates by completing the following steps:
#
# 1. Select three dates to evaluate for arbitrage profitability. Choose one date that’s early in the dataset, one from the middle of the dataset, and one from the later part of the time period.
#
# 2. For each of the three dates, generate the summary statistics and then create a box plot. This big-picture view is meant to help you gain a better understanding of the data before you perform your arbitrage calculations. As you compare the data, what conclusions can you draw?

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day early in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp['Close'].loc['2018-01-28'].plot(kind='line', legend=True, figsize=(15,10),title='28th January 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-01-28'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'28th January 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Using the early date that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_early = bitstamp['Low'].loc['2018-01-28']-coinbase['High'].loc['2018-01-28']
arbitrage_spread_early.dtypes
# Generate summary statistics for the early DataFrame
# YOUR CODE HERE
display("************************ Arbitrage_Spread_Early DF********************************")
arbitrage_spread_early.describe()
# Out:
# '************************ Arbitrage_Spread_Early DF********************************'
# count    1436.000000
# mean      230.585508
# std        68.274748
# min        -5.360000
# 25%       197.102500
# 50%       236.100000
# 75%       271.782500
# max       420.000000
# dtype: float64

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
# YOUR CODE HERE
arbitrage_spread_early.plot(kind='box',title='Arbitrage Spread Early dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Early dataset'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from the middle of the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp['Close'].loc['2018-02-24'].plot(kind='line', legend=True, figsize=(15,10),title='24th February 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-02-24'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'24th February 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Using the date in the middle that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_middle = coinbase['High'].loc['2018-02-24'] - bitstamp['Low'].loc['2018-02-24']

# Generate summary statistics 
# YOUR CODE HERE
display("************************ Arbitrage_Spread_Middle DF********************************")
arbitrage_spread_middle.describe()
# Out:
# '************************ Arbitrage_Spread_Middle DF********************************'
# count    1437.000000
# mean       19.951239
# std        27.701967
# min       -35.000000
# 25%         2.010000
# 50%        14.630000
# 75%        29.480000
# max       175.380000
# dtype: float64

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
# YOUR CODE HERE
arbitrage_spread_middle.plot(kind='box',title='Arbitrage Spread Middle dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Middle dataset'}>

# %%
# Create an overlay plot that visualizes the two dataframes over a period of one day from late in the dataset. 
# Be sure that the plots include the parameters `legend`, `figsize`, `title`, `color` and `label` 
# YOUR CODE HERE
bitstamp['Close'].loc['2018-03-31'].plot(kind='line', legend=True, figsize=(15,10),title='31st March 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-03-31'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'31st March 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Using the date from the late that you have selected, calculate the arbitrage spread 
# by subtracting the bitstamp lower closing prices from the coinbase higher closing prices
arbitrage_spread_late = coinbase['High'].loc['2018-03-31'] - bitstamp['Low'].loc['2018-03-31']

# Generate summary statistics for the late DataFrame
# YOUR CODE HERE
display("************************ Arbitrage_Spread_Late DF********************************")
arbitrage_spread_late.describe()
# Out:
# '************************ Arbitrage_Spread_Late DF********************************'
# count    1434.000000
# mean       11.625418
# std        10.717973
# min       -23.000000
# 25%         4.970000
# 50%        10.550000
# 75%        16.427500
# max        80.960000
# dtype: float64

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
# YOUR CODE HERE
arbitrage_spread_late.plot(kind='box',title='Arbitrage Spread Late dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Late dataset'}>

# %% [markdown]
# ### Step 4: Calculate the Arbitrage Profits
#
# Calculate the potential profits for each date that you selected in the previous section. Your goal is to determine whether arbitrage opportunities still exist in the Bitcoin market. Complete the following steps:
#
# 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.
#
# 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.
#
# 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?
#
# 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.
#
# 6. Generate the summary statistics, and plot the results for each of the three DataFrames.
#
# 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.
#
# 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?
#
# (NOTE: The starter code displays only one date. You'll want to do this analysis for two additional dates).

# %% [markdown]
# #### 1. For each of the three dates, measure the arbitrage spread between the two exchanges by subtracting the lower-priced exchange from the higher-priced one. Then use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame, where the spread is greater than zero.
#
# *NOTE*: For illustration, only one of the three dates is shown in the starter code below.

# %%
# For the date early in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_early = bitstamp['Close'].loc['2018-01-28'] - coinbase['Close'].loc['2018-01-28']
display(arbitrage_spread_early.describe())

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Early Date Statistics : Arbitrage Spread greater than zero ***************************")
arbitrage_spread_early[arbitrage_spread_early>0].describe()
# Out:
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# Name: Close, dtype: float64
# '************************** Early Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# Name: Close, dtype: float64

# %%
# For the date middle in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_middle = bitstamp['Close'].loc['2018-02-24'] - coinbase['Close'].loc['2018-02-24']
display(arbitrage_spread_middle.describe())

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Middle Date Statistics : Arbitrage Spread greater than zero ***************************")
arbitrage_spread_middle[arbitrage_spread_middle>0].describe()
# Out:
# count    1437.000000
# mean       -3.396131
# std        22.969472
# min      -121.320000
# 25%       -12.120000
# 50%         0.010000
# 75%        10.590000
# max        50.180000
# Name: Close, dtype: float64
# '************************** Middle Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    719.000000
# mean      12.926912
# std        9.672629
# min        0.010000
# 25%        5.335000
# 50%       10.590000
# 75%       18.245000
# max       50.180000
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, measure the arbitrage spread between the two exchanges
# by subtracting the lower-priced exchange from the higher-priced one
arbitrage_spread_late = bitstamp['Close'].loc['2018-03-31'] - coinbase['Close'].loc['2018-03-31']
display(arbitrage_spread_late.describe())

# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Late Date Statistics : Arbitrage Spread greater than zero ***************************")
arbitrage_spread_late[arbitrage_spread_late>0].describe()
# Out:
# count    1434.000000
# mean       -2.348675
# std         8.109623
# min       -35.980000
# 25%        -7.627500
# 50%        -2.300000
# 75%         2.537500
# max        35.000000
# Name: Close, dtype: float64
# '************************** Late Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    514.000000
# mean       5.905233
# std        4.905227
# min        0.010000
# 25%        2.042500
# 50%        4.820000
# 75%        8.777500
# max       35.000000
# Name: Close, dtype: float64

# %% [markdown]
# #### 2. For each of the three dates, calculate the spread returns. To do so, divide the instances that have a positive arbitrage spread (that is, a spread greater than zero) by the price of Bitcoin from the exchange you’re buying on (that is, the lower-priced exchange). Review the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_early= arbitrage_spread_early[arbitrage_spread_early>0]/coinbase['Close'].loc['2018-01-28']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_early.describe()
# Out:
# count    1436.000000
# mean        0.021648
# std         0.005961
# min         0.004885
# 25%         0.018369
# 50%         0.021897
# 75%         0.025292
# max         0.038510
# Name: Close, dtype: float64

# %%
# For the date middle in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_middle= arbitrage_spread_middle[arbitrage_spread_middle>0]/coinbase['Close'].loc['2018-02-24']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_middle.describe()
# Out:
# count    719.000000
# mean       0.001301
# std        0.000954
# min        0.000001
# 25%        0.000544
# 50%        0.001090
# 75%        0.001843
# max        0.005074
# Name: Close, dtype: float64

# %%
# For the date late in the dataset, calculate the spread returns by dividing the instances when the arbitrage spread is positive (> 0) 
# by the price of Bitcoin from the exchange you are buying on (the lower-priced exchange).
spread_return_late= arbitrage_spread_late[arbitrage_spread_late>0]/coinbase['Close'].loc['2018-03-31']

# Review the spread return DataFrame
# YOUR CODE HERE
spread_return_late.describe()
# Out:
# count    514.000000
# mean       0.000844
# std        0.000698
# min        0.000001
# 25%        0.000292
# 50%        0.000696
# 75%        0.001249
# max        0.004885
# Name: Close, dtype: float64

# %% [markdown]
# #### 3. For each of the three dates, narrow down your trading opportunities even further. To do so, determine the number of times your trades with positive returns exceed the 1% minimum threshold that you need to cover your costs.

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early>.01]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_early.head()
# Out:
# Timestamp
# 2018-01-28 00:00:00    0.023999
# 2018-01-28 00:01:00    0.023965
# 2018-01-28 00:02:00    0.023392
# 2018-01-28 00:03:00    0.023936
# 2018-01-28 00:04:00    0.025610
# Name: Close, dtype: float64

# %%
# For the date middle in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
display("*********** Profitable trades greater than 0 **************************")
profitable_trades_middle = spread_return_middle[spread_return_middle>0]
display(profitable_trades_middle)

display("*********** Profitable trades greater than 1% **************************")
profitable_trades_middle = spread_return_middle[spread_return_middle>=.01]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_middle.head()
# Out:
# '*********** Profitable trades greater than 0 **************************'
# Timestamp
# 2018-02-24 00:00:00    0.002313
# 2018-02-24 00:01:00    0.002897
# 2018-02-24 00:02:00    0.002851
# 2018-02-24 00:03:00    0.003819
# 2018-02-24 00:04:00    0.002383
#                          ...
# 2018-02-24 23:55:00    0.001546
# 2018-02-24 23:56:00    0.000717
# 2018-02-24 23:57:00    0.002129
# 2018-02-24 23:58:00    0.000763
# 2018-02-24 23:59:00    0.001370
# Name: Close, Length: 719, dtype: float64
# '*********** Profitable trades greater than 1% **************************'
# Series([], Name: Close, dtype: float64)

# %%
# For the date late in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
display("*********** Profitable trades greater than 0 **************************")
profitable_trades_late = spread_return_late[spread_return_late>0]
display(profitable_trades_late)

display("*********** Profitable trades greater than 1% **************************")
profitable_trades_late = spread_return_late[spread_return_late>=.01]
# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_late.head()
# Out:
# '*********** Profitable trades greater than 0 **************************'
# Timestamp
# 2018-03-31 00:03:00    0.000428
# 2018-03-31 00:04:00    0.000352
# 2018-03-31 00:05:00    0.001428
# 2018-03-31 00:06:00    0.001813
# 2018-03-31 00:07:00    0.000312
#                          ...
# 2018-03-31 23:22:00    0.002165
# 2018-03-31 23:23:00    0.000723
# 2018-03-31 23:24:00    0.000165
# 2018-03-31 23:27:00    0.000286
# 2018-03-31 23:57:00    0.000117
# Name: Close, Length: 514, dtype: float64
# '*********** Profitable trades greater than 1% **************************'
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# #### 4. Generate the summary statistics of your spread returns that are greater than 1%. How do the average returns compare among the three dates?

# %%
# For the date early in the dataset, generate the summary statistics for the profitable trades
# or you trades where the spread returns are are greater than 1%
# YOUR CODE HERE
display("********************************* EARLY DATE TRADES STATISTICS***************************")
display(profitable_trades_early.describe())

display("********************************* MIDDLE DATE TRADES STATISTICS***************************")
display(profitable_trades_middle.describe())


display("********************************* LATE DATE TRADES STATISTICS***************************")
display(profitable_trades_late.describe())
# Out:
# '********************************* EARLY DATE TRADES STATISTICS***************************'
# count    1378.000000
# mean        0.022201
# std         0.005421
# min         0.010087
# 25%         0.019016
# 50%         0.022191
# 75%         0.025413
# max         0.038510
# Name: Close, dtype: float64
# '********************************* MIDDLE DATE TRADES STATISTICS***************************'
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64
# '********************************* LATE DATE TRADES STATISTICS***************************'
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Close, dtype: float64

# %%
#display(profitable_trades_early)

# %% [markdown]
# #### 5. For each of the three dates, calculate the potential profit, in dollars, per trade. To do so, multiply the spread returns that were greater than 1% by the cost of what was purchased. Make sure to drop any missing values from the resulting DataFrame.

# %%
# For the date early in the dataset, calculate the potential profit per trade in dollars 
# Multiply the profitable trades by the cost of the Bitcoin that was purchased
profit_early = profitable_trades_early.loc['2018-01-28']*coinbase['Close'].loc['2018-01-28']

# Drop any missing values from the profit DataFrame
profit_per_trade_early = profit_early.dropna()

# View the early profit DataFrame
display(profit_per_trade_early)

# Check for number of profitable trades for middle date and calculate profit per trade'
if(profitable_trades_middle.sum()):
    profit_middle = profitable_trades_middle.loc['2018-02-24']*coinbase['Close'].loc['2018-02-24']
    profit_per_trade_middle = profit_middle.dropna()
    display(profit_per_trade_middle)
else:
    display("No profitable trades greater than 1% by cost for middle date")
    
display("******************************************************************************")

# Check for number of profitable trades for late date and calculate profit per trade'    
if(profitable_trades_late.sum()):
    profit_late = profitable_trades_late.loc['2018-03-31']*coinbase['Close'].loc['2018-03-31']
    profit_per_trade_late = profit_late.dropna()
    display(profit_per_trade_late)
else:
    display("No profitable trades greater than 1% by cost for late date")
# Out:
# Timestamp
# 2018-01-28 00:00:00    275.38
# 2018-01-28 00:01:00    275.00
# 2018-01-28 00:02:00    268.77
# 2018-01-28 00:03:00    275.03
# 2018-01-28 00:04:00    294.26
#                         ...
# 2018-01-28 23:55:00    220.10
# 2018-01-28 23:56:00    195.11
# 2018-01-28 23:57:00    208.74
# 2018-01-28 23:58:00    195.12
# 2018-01-28 23:59:00    192.63
# Name: Close, Length: 1378, dtype: float64
# 'No profitable trades greater than 1% by cost for middle date'
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for late date'

# %% [markdown]
# #### 6. Generate the summary statistics, and plot the results for each of the three DataFrames.

# %%
# Generate the summary statistics for the early profit per trade DataFrame
# YOUR CODE HERE
display(profit_per_trade_early.describe())

# Check for number of profitable trades for middle date and generate statistics.
if(profitable_trades_middle.sum()):
    display(profit_per_trade_middle.describe())
else:
    display("No profitable trades greater than 1% by cost for middle date")
    
display("******************************************************************************")

# Check for number of profitable trades for late date and generate statistics.    
if(profitable_trades_late.sum()):
    display(profit_per_trade_late.describe())
else:
    display("No profitable trades greater than 1% by cost for late date")
# Out:
# count    1378.000000
# mean      253.931996
# std        62.057953
# min       113.970000
# 25%       217.272500
# 50%       254.150000
# 75%       292.987500
# max       439.010000
# Name: Close, dtype: float64
# 'No profitable trades greater than 1% by cost for middle date'
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for late date'

# %%
# Plot the results for the early profit per trade DataFrame
# YOUR CODE HERE
profit_per_trade_early.plot(figsize=(15,10), legend=True, title='Profitable trades on a early date during the time period',
                            color='green',label='Arbitrage per trade for 1BTC in USD')
# Out:
# <AxesSubplot:title={'center':'Profitable trades on a early date during the time period'}, xlabel='Timestamp'>

# %%
# Check for number of profitable trades for middle date then plot the chart.
if(profitable_trades_middle.sum()):
    profit_per_trade_middle.plot(figsize=(15,10), legend=True, title='Profitable trades on a middle date during the time period',
                            color='orange',label='Arbitrage per trade for 1BTC in USD')
else:
    display("No profitable trades greater than 1% by cost for middle date")
    
display("******************************************************************************")

# Check for number of profitable trades for late date and generate statistics.    
if(profitable_trades_late.sum()):
    profit_per_trade_late.plot(figsize=(15,10), legend=True, title='Profitable trades on a late date during the time period',
                            color='red',label='Arbitrage per trade for 1BTC in USD')
else:
    display("No profitable trades greater than 1% by cost for late date")
# Out:
# 'No profitable trades greater than 1% by cost for middle date'
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for late date'

# %% [markdown]
# #### 7. Calculate the potential arbitrage profits that you can make on each day. To do so, sum the elements in the profit_per_trade DataFrame.

# %%
# Calculate the sum of the potential profits for the early profit per trade DataFrame
# YOUR CODE HERE

print(f"Potential arbitrage profits that can be made on a early day in the time period = USD ${profit_per_trade_early.sum():.2f}")
display("******************************************************************************")

# Check for number of profitable trades for middle date then calculate potential profit.
if(profitable_trades_middle.sum()):
    print(f"Potential arbitrage profits that can be made on a middle day in the time period = USD ${profitable_trades_middle.sum():.2f}")
else:
    display("No profitable trades greater than 1% by cost for middle date")
    
display("******************************************************************************")

# Check for number of profitable trades for late date then calculate potential profit.    
if(profitable_trades_late.sum()):
    print(f"Potential arbitrage profits that can be made on a late day in the time period = USD ${profitable_trades_late.sum():.2f}")
else:
    display("No profitable trades greater than 1% by cost for late date")
# Out:
# Potential arbitrage profits that can be made on a early day in the time period = USD $349918.29
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for middle date'
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for late date'

# %% [markdown]
# #### 8. Using the `cumsum` function, plot the cumulative sum of each of the three DataFrames. Can you identify any patterns or trends in the profits across the three time periods?

# %%
# Use the cumsum function to calculate the cumulative profits over time for the early profit per trade DataFrame
cumulative_profit_early = profit_per_trade_early.cumsum()
print(f"Potential arbitrage cumulative profit that can be made on a middle day in the time period = USD ${cumulative_profit_early}")    
display("******************************************************************************")

# Check for number of profitable trades for middle date then calculate potential profit.
if(profitable_trades_middle.sum()):
    print(f"Potential arbitrage cumulative profit that can be made on a middle day in the time period = USD ${profitable_trades_middle.cumsum()}")
else:
    display("No profitable trades greater than 1% by cost for middle date")
    
display("******************************************************************************")

# Check for number of profitable trades for late date then calculate potential profit.    
if(profitable_trades_late.sum()):
    print(f"Potential arbitrage profits that can be made on a late day in the time period = USD ${profitable_trades_late.cumsum()}")
else:
    display("No profitable trades greater than 1% by cost for late date")
# Out:
# Potential arbitrage cumulative profit that can be made on a middle day in the time period = USD $Timestamp
# 2018-01-28 00:00:00       275.38
# 2018-01-28 00:01:00       550.38
# 2018-01-28 00:02:00       819.15
# 2018-01-28 00:03:00      1094.18
# 2018-01-28 00:04:00      1388.44
#                          ...
# 2018-01-28 23:55:00    349126.69
# 2018-01-28 23:56:00    349321.80
# 2018-01-28 23:57:00    349530.54
# 2018-01-28 23:58:00    349725.66
# 2018-01-28 23:59:00    349918.29
# Name: Close, Length: 1378, dtype: float64
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for middle date'
# '******************************************************************************'
# 'No profitable trades greater than 1% by cost for late date'

# %%
# Plot the cumulative sum of profits for the early profit per trade DataFrame
# YOUR CODE HERE
cumulative_profit_early.plot(kind='line',figsize=(15,10),title='Cumulative profit chart',legend=True,color='blue',label='early days profit in USD$')
# Out:
# <AxesSubplot:title={'center':'Cumulative profit chart'}, xlabel='Timestamp'>

# %% [markdown]
# **Question:** After reviewing the profit information across each date from the different time periods, can you identify any patterns or trends?
#
# **Answer:** Arbitrage trade spread decreased over the period. The minimum hurdle rate of 1% profit was possible in the early days, but during the middle and later periods, profitability fell under 1% per trade. This makes arbitrage not a profitable strategy for the given period and data set.

# %% [markdown]
# ***Final Analysis***
# ______________________
# Analyzing the data from Bitstamp and Coinbase exchange for the three months in 2018 from January to March we discover the spread between them reduced.
# For the three selected dates of Jan 28th, Feb 24th and March 31st, we notice the profitability calculated for these dates reduces consistently.
#
# While on Jan 28th there are multiple trading opportunities with profit exceeding 1% to account for fees, on middle and later dates, there are opportunities for profitable trade but none above the 1% minimum threshold.

# %%
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Early Date Statistics : Arbitrage Spread greater than zero ***************************")
display(arbitrage_spread_early[arbitrage_spread_early>0].describe())
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Middle Date Statistics : Arbitrage Spread greater than zero ***************************")
display(arbitrage_spread_middle[arbitrage_spread_middle>0].describe())
# Use a conditional statement to generate the summary statistics for each arbitrage_spread DataFrame
# YOUR CODE HERE
display("************************** Late Date Statistics : Arbitrage Spread greater than zero ***************************")
display(arbitrage_spread_late[arbitrage_spread_late>0].describe())
# Out:
# '************************** Early Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    1436.000000
# mean      247.552326
# std        68.343472
# min        55.030000
# 25%       210.022500
# 50%       251.180000
# 75%       290.925000
# max       439.010000
# Name: Close, dtype: float64
# '************************** Middle Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    719.000000
# mean      12.926912
# std        9.672629
# min        0.010000
# 25%        5.335000
# 50%       10.590000
# 75%       18.245000
# max       50.180000
# Name: Close, dtype: float64
# '************************** Late Date Statistics : Arbitrage Spread greater than zero ***************************'
# count    514.000000
# mean       5.905233
# std        4.905227
# min        0.010000
# 25%        2.042500
# 50%        4.820000
# 75%        8.777500
# max       35.000000
# Name: Close, dtype: float64

# %% [markdown]
# ------------
# **The arbitrage spread for these three dates shows a consistent fall in the number of trades > 0.**
#
# 1. Jan 28th = **1436**
# 2. Feb 24th = **719**
# 3. March 31st = **514**

# %%
# For the date early in the dataset, determine the number of times your trades with positive returns 
# exceed the 1% minimum threshold (.01) that you need to cover your costs
profitable_trades_early = spread_return_early[spread_return_early>.01]

# Review the first five profitable trades
# YOUR CODE HERE
display(profitable_trades_early.head())

display("*********** Profitable trades greater than 1% for Middle date **************************")
profitable_trades_middle = spread_return_middle[spread_return_middle>=.01]

# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_middle.head()
display("*********** Profitable trades greater than 1% for Late date **************************")
profitable_trades_late = spread_return_late[spread_return_late>=.01]
# Review the first five profitable trades
# YOUR CODE HERE
profitable_trades_late.head()
# Out:
# Timestamp
# 2018-01-28 00:00:00    0.023999
# 2018-01-28 00:01:00    0.023965
# 2018-01-28 00:02:00    0.023392
# 2018-01-28 00:03:00    0.023936
# 2018-01-28 00:04:00    0.025610
# Name: Close, dtype: float64
# '*********** Profitable trades greater than 1% for Middle date **************************'
# '*********** Profitable trades greater than 1% for Late date **************************'
# Series([], Name: Close, dtype: float64)

# %% [markdown]
# _____________
# **The last two dates return zero results after further investigation on probable trades >0 and clearing the minimum threshold of greater than 1% profit.**

# %% [markdown]
# ## Visualization
# ____________

# %%
# Line plot of closing prices on Jan 28th
bitstamp['Close'].loc['2018-01-28'].plot(kind='line', legend=True, figsize=(15,10),title='28th January 2018 BTC Closing price on Bitstamp Vs Coinbase', color='orange', label='Bitstamp')
coinbase['Close'].loc['2018-01-28'].plot(kind='line', legend=True, figsize=(15,10), color='blue', label='Coinbase')
# Out:
# <AxesSubplot:title={'center':'28th January 2018 BTC Closing price on Bitstamp Vs Coinbase'}, xlabel='Timestamp'>

# %%
# Visualize the arbitrage spread from early in the dataset in a box plot
arbitrage_spread_early.plot(kind='box',title='Arbitrage Spread Early dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Early dataset'}>

# %%
# Visualize the arbitrage spread from the middle of the dataset in a box plot
arbitrage_spread_middle.plot(kind='box',title='Arbitrage Spread Middle dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Middle dataset'}>

# %%
# Visualize the arbitrage spread from late in the dataset in a box plot
arbitrage_spread_late.plot(kind='box',title='Arbitrage Spread Late dataset',figsize=(15,10))
# Out:
# <AxesSubplot:title={'center':'Arbitrage Spread Late dataset'}>

# %% [markdown]
# ------------
# **The box plots highlight median transaction profits moving closer to zero for the last two dates.**
